# %% [markdown]
# <a href="https://colab.research.google.com/github/bansal-shiv/Credit-card-validator/blob/main/EXP_2_Shivang_Bansal_242211018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as num
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Loan dataset train.csv')

# %%
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
plt.hist(df['ApplicantIncome'])
plt.show()

# %%
sns.countplot(x='Property_Area',data=df)
plt.show()

# %%
import seaborn as sns

# %%
sns.countplot(x='Property_Area', data = df)
# Out:
# <Axes: xlabel='Property_Area', ylabel='count'>

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#scatter plot

y = df['LoanAmount']
x = df['Property_Area']

plt.scatter(x , y , c='red')

# %%
sns.violinplot(data=df, x="LoanAmount", y="Education")
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Education'>

# %%
sns.pairplot(df[['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']])
plt.show()

# %%
import scipy.stats as stats

# %%
 #QQplot

plt.figure(figsize=(10, 8))
stats.probplot(df['LoanAmount'].dropna(), dist="norm", plot=plt)
plt.title('Q-Q Plot for Loan Amount')
plt.show()

# %%
# heatmap
numerical_df = df.select_dtypes(include=['number'])
corr_matrix = numerical_df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
#performed by Shivang Bansal 242211018 CSA

# %% [markdown]
# # New section
